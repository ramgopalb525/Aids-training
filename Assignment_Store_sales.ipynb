# %% [markdown]
# <a href="https://colab.research.google.com/github/kandurisripaada/aids-lab/blob/main/Assignment_Store_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment on Store_sales dataset
#
# **Load the Dataset**

# %%
import pandas as pd
df=pd.read_csv("store_sales.csv")
print(df.head(5))
df.info()
# Out:
#   store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0      S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1      S_2  California   12   19   15   15   11   19     7   15   10   11
# 2      S_3  California   16   16   14   19   23    6    13   13   15   14
# 3      S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4      S_5       Texas   19    5   24    9    5   24    10    5   24   15
#
#    Nov  Dec
# 0    7    6
# 1   21   19
# 2   24    8
# 3    7   11
# 4    6   13
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   store_id  100 non-null    object
#  1   city      100 non-null    object
#  2   Jan       100 non-null    int64
#  3   Feb       100 non-null    int64
#  4   Mar       100 non-null    int64
#  5   Apr       100 non-null    int64
#  6   May       100 non-null    int64
#  7   Jun       100 non-null    int64
#  8   July      100 non-null    int64
#  9   Aug       100 non-null    int64
#  10  Sep       100 non-null    int64
#  11  Oct       100 non-null    int64
#  12  Nov       100 non-null    int64
#  13  Dec       100 non-null    int64
# dtypes: int64(12), object(2)
# memory usage: 11.1+ KB

# %% [markdown]
# **Calculate the total sales for each store across all months.**

# %%
df['total_sales'] = df.iloc[:, 2:].sum(axis=1)
df[['store_id', 'total_sales']]
# Out:
#    store_id  total_sales
# 0       S_1        178.0
# 1       S_2        174.0
# 2       S_3        181.0
# 3       S_4        135.0
# 4       S_5        159.0
# ..      ...          ...
# 95     S_96        185.0
# 96     S_97        154.0
# 97     S_98        168.0
# 98     S_99        173.0
# 99    S_100        180.0
#
# [100 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['total_sales'].plot(kind='hist', bins=20, title='total_sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['total_sales'].plot(kind='line', figsize=(8, 4), title='total_sales')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# **Find the average sales for each month across all stores**

# %%
avg_sales = df.iloc[:, 2:].mean()
avg_sales
# Out:
# Jan             14.46
# Feb             15.09
# Mar             14.56
# Apr             14.57
# May             13.56
# Jun             13.80
# July            14.38
# Aug             15.81
# Sep             14.91
# Oct             14.10
# Nov             15.31
# Dec             13.57
# total_sales    174.12
# dtype: float64

# %% [markdown]
# **Identify the store with the highest total sales.**

# %%
df['total_sales'] = df.iloc[:, 2:].sum(axis=1)
max_sales_store = df.loc[df['total_sales'].idxmax()]
max_sales_store
# Out:
# store_id             S_62
# city           California
# Jan                    16
# Feb                    21
# Mar                     6
# Apr                    22
# May                    22
# Jun                     9
# July                   21
# Aug                    21
# Sep                    22
# Oct                    17
# Nov                    16
# Dec                    21
# total_sales        1284.0
# Name: 61, dtype: object

# %% [markdown]
# **Calculate the total sales for each city.**

# %%
df['total_sales'] = df.iloc[:, 2:].sum(axis=1)
city_sales = df.groupby('city')['total_sales'].sum()
city_sales
# Out:
# city
# Arizona       27657.0
# California    52654.0
# Texas         41573.0
# Name: total_sales, dtype: float64

# %% [markdown]
# **List stores with total sales greater than 200**

# %%
df['total_sales'] = df.iloc[:, 2:].sum(axis=1)
df_200=df[df['total_sales']>200]
df_200[['store_id','total_sales']]
# Out:
#    store_id  total_sales
# 0       S_1       1424.0
# 1       S_2       1392.0
# 2       S_3       1448.0
# 3       S_4       1080.0
# 4       S_5       1272.0
# ..      ...          ...
# 95     S_96       1480.0
# 96     S_97       1232.0
# 97     S_98       1344.0
# 98     S_99       1384.0
# 99    S_100       1440.0
#
# [100 rows x 2 columns]

# %% [markdown]
# **Which month had the highest average sales across all stores?**

# %%
avg_sales = df.iloc[:, 2:14].mean()
highest=avg_sales.idxmax()
highest
# Out:
# 'Aug'

# %% [markdown]
# **Which city generated the most revenue?**

# %%
df['total_sales'] = df.iloc[:, 2:].sum(axis=1)
city_sales = df.groupby('city')['total_sales'].sum()
high=city_sales.idxmax()
high
# Out:
# 'California'
